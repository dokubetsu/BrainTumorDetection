# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import zipfile

zip_file_path = '/content/drive/My Drive/archive.zip'
extract_folder_path = '/content/BrainTumour_Dataset/'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder_path)

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

# Update this path to where the dataset was unzipped
data_dir = '/content/BrainTumour_Dataset/Training/'
categories = ['glioma', 'meningioma', 'notumor', 'pituitary']
# Image Size Distribution
def plot_image_size_distribution(data_dir, categories):
    image_sizes = []
    for category in categories:
        category_path = os.path.join(data_dir, category)
        for img_name in os.listdir(category_path):
            img_path = os.path.join(category_path, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            image_sizes.append(img.shape)

    image_sizes = np.array(image_sizes)
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.hist(image_sizes[:, 0], bins=20, color='orange', alpha=0.7)
    plt.title("Image Height Distribution")
    plt.xlabel("Height (pixels)")
    plt.ylabel("Frequency")

    plt.subplot(1, 2, 2)
    plt.hist(image_sizes[:, 1], bins=20, color='cyan', alpha=0.7)
    plt.title("Image Width Distribution")
    plt.xlabel("Width (pixels)")
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()

plot_image_size_distribution(data_dir, categories)

# %%
import numpy as np
for category in categories:
    image_path = os.path.join(data_dir, category)
    images = [cv2.imread(os.path.join(image_path, img), 0) for img in os.listdir(image_path)]
    pixel_values = [np.mean(img) for img in images]
    plt.hist(pixel_values, bins=50, alpha=0.5, label=category)

plt.legend()
plt.title('Pixel Intensity Distribution')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.show()

# %%
# Class Distribution
def plot_class_distribution(data_dir, categories):
    class_counts = {}
    for category in categories:
        class_counts[category] = len(os.listdir(os.path.join(data_dir, category)))

    plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'green', 'red', 'purple'])
    plt.title("Class Distribution")
    plt.xlabel("Tumor Category")
    plt.ylabel("Number of Images")
    plt.show()

plot_class_distribution(data_dir, categories)

# %%
def analyze_aspect_ratio(data_dir, categories):
    aspect_ratios = []
    for category in categories:
        category_path = os.path.join(data_dir, category)
        img_list = os.listdir(category_path)

        for img_name in img_list:
            img_path = os.path.join(category_path, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                aspect_ratio = img.shape[1] / img.shape[0]
                aspect_ratios.append(aspect_ratio)

    plt.hist(aspect_ratios, bins=50, color='skyblue', alpha=0.7)
    plt.title("Aspect Ratio Distribution")
    plt.xlabel("Aspect Ratio (Width/Height)")
    plt.ylabel("Frequency")
    plt.show()

analyze_aspect_ratio(data_dir, categories)

# %%
def load_sample_image(data_dir, category):
    category_path = os.path.join(data_dir, category)
    sample_image_name = os.listdir(category_path)[0]  # Load the first image in the folder
    sample_image_path = os.path.join(category_path, sample_image_name)
    sample_image = cv2.imread(sample_image_path, cv2.IMREAD_GRAYSCALE)
    return sample_image

# Visualize the image and its pixel intensity distribution
def visualize_image(image, category_name):
    # Plot the image
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Sample Image from '{category_name}' Category")
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# Load and visualize a sample image from one category
for category in categories:  # Choose a category to visualize
    sample_image = load_sample_image(data_dir, category)
    visualize_image(sample_image, category)

# %%
import hashlib

def dhash(image, hash_size=8):
    resized = cv2.resize(image, (hash_size + 1, hash_size))
    diff = resized[:, 1:] > resized[:, :-1]
    return sum([2 ** i for (i, v) in enumerate(diff.flatten()) if v])

def remove_duplicates(data_dir):
    image_hashes = {}
    duplicates = []

    for category in os.listdir(data_dir):
        category_path = os.path.join(data_dir, category)

        for img_name in os.listdir(category_path):
            img_path = os.path.join(category_path, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            img_hash = dhash(img)

            if img_hash in image_hashes:
                print(f"Duplicate found: {img_name} is a duplicate of {image_hashes[img_hash]}")
                duplicates.append(img_path)
            else:
                image_hashes[img_hash] = img_name

    for duplicate in duplicates:
        os.remove(duplicate)
        print(f"Deleted duplicate image: {duplicate}")

remove_duplicates(data_dir)
# Out:
# Duplicate found: Tr-me_0366.jpg is a duplicate of Tr-me_0211.jpg
# Duplicate found: Tr-me_0249.jpg is a duplicate of Tr-me_0251.jpg
# Duplicate found: Tr-me_0616.jpg is a duplicate of Tr-me_0617.jpg
# Duplicate found: Tr-me_0238.jpg is a duplicate of Tr-me_0227.jpg
# Duplicate found: Tr-me_0175.jpg is a duplicate of Tr-me_0281.jpg
# Duplicate found: Tr-me_0176.jpg is a duplicate of Tr-me_0211.jpg
# Duplicate found: Tr-pi_0676.jpg is a duplicate of Tr-pi_0677.jpg
# Duplicate found: Tr-pi_0518.jpg is a duplicate of Tr-pi_0517.jpg
# Duplicate found: Tr-pi_0321.jpg is a duplicate of Tr-pi_0320.jpg
# Duplicate found: Tr-pi_0160.jpg is a duplicate of Tr-pi_0159.jpg
# Duplicate found: Tr-pi_0108.jpg is a duplicate of Tr-pi_0107.jpg
# Duplicate found: Tr-pi_0169.jpg is a duplicate of Tr-pi_0170.jpg
# Duplicate found: Tr-pi_0157.jpg is a duplicate of Tr-pi_0046.jpg
# Duplicate found: Tr-pi_0526.jpg is a duplicate of Tr-pi_0529.jpg
# Duplicate found: Tr-pi_0342.jpg is a duplicate of Tr-pi_0343.jpg
# Duplicate found: Tr-pi_0226.jpg is a duplicate of Tr-pi_0227.jpg
# Duplicate found: Tr-pi_0527.jpg is a duplicate of Tr-pi_0529.jpg
# Duplicate found: Tr-pi_0516.jpg is a duplicate of Tr-pi_0517.jpg
# Duplicate found: Tr-no_0117.jpg is a duplicate of Tr-no_0131.jpg
# Duplicate found: Tr-no_0226.jpg is a duplicate of Tr-no_1127.jpg
# Duplicate found: Tr-no_0056.jpg is a duplicate of Tr-no_0224.jpg
# Duplicate found: Tr-no_0291.jpg is a duplicate of Tr-no_0324.jpg
# Duplicate found: Tr-no_0164.jpg is a duplicate of Tr-no_0150.jpg
# Duplicate found: Tr-no_1538.jpg is a duplicate of Tr-no_0845.jpg
# Duplicate found: Tr-no_0077.jpg is a duplicate of Tr-no_0072.jpg
# Duplicate found: Tr-no_0711.jpg is a duplicate of Tr-no_1482.jpg
# Duplicate found: Tr-no_1500.jpg is a duplicate of Tr-no_1405.jpg
# Duplicate found: Tr-noTr_0006.jpg is a duplicate of Tr-no_1047.jpg
# Duplicate found: Tr-no_1098.jpg is a duplicate of Tr-no_1479.jpg
# Duplicate found: Tr-no_0331.jpg is a duplicate of Tr-no_0373.jpg
# Duplicate found: Tr-no_1045.jpg is a duplicate of Tr-no_1482.jpg
# Duplicate found: Tr-no_1110.jpg is a duplicate of Tr-no_0157.jpg
# Duplicate found: Tr-no_0031.jpg is a duplicate of Tr-no_1072.jpg
# Duplicate found: Tr-no_1055.jpg is a duplicate of Tr-no_0013.jpg
# Duplicate found: Tr-no_1069.jpg is a duplicate of Tr-no_1193.jpg
# Duplicate found: Tr-no_1026.jpg is a duplicate of Tr-no_0560.jpg
# Duplicate found: Tr-no_1042.jpg is a duplicate of Tr-no_1481.jpg
# Duplicate found: Tr-no_1053.jpg is a duplicate of Tr-no_0565.jpg
# Duplicate found: Tr-no_1182.jpg is a duplicate of Tr-no_0246.jpg
# Duplicate found: Tr-no_1490.jpg is a duplicate of Tr-no_0511.jpg
# Duplicate found: Tr-no_0236.jpg is a duplicate of Tr-no_1133.jpg
# Duplicate found: Tr-no_0282.jpg is a duplicate of Tr-no_0148.jpg
# Duplicate found: Tr-no_0142.jpg is a duplicate of Tr-no_0143.jpg
# Duplicate found: Tr-no_1303.jpg is a duplicate of Tr-no_0625.jpg
# Duplicate found: Tr-no_1104.jpg is a duplicate of Tr-no_0148.jpg
# Duplicate found: Tr-no_0399.jpg is a duplicate of Tr-no_1511.jpg
# Duplicate found: Tr-no_0714.jpg is a duplicate of Tr-no_1477.jpg
# Duplicate found: Tr-no_0766.jpg is a duplicate of Tr-no_0550.jpg
# Duplicate found: Tr-no_0423.jpg is a duplicate of Tr-no_1405.jpg
# Duplicate found: Tr-no_0366.jpg is a duplicate of Tr-no_0131.jpg
# Duplicate found: Tr-no_0152.jpg is a duplicate of Tr-no_1107.jpg
# Duplicate found: Tr-no_1179.jpg is a duplicate of Tr-no_0185.jpg
# Duplicate found: Tr-no_0313.jpg is a duplicate of Tr-no_1166.jpg
# Duplicate found: Tr-no_0199.jpg is a duplicate of Tr-no_1044.jpg
# Duplicate found: Tr-no_0073.jpg is a duplicate of Tr-no_0078.jpg
# Duplicate found: Tr-no_0168.jpg is a duplicate of Tr-no_1122.jpg
# Duplicate found: Tr-no_0294.jpg is a duplicate of Tr-no_1255.jpg
# Duplicate found: Tr-no_0140.jpg is a duplicate of Tr-no_1101.jpg
# Duplicate found: Tr-no_1256.jpg is a duplicate of Tr-no_1076.jpg
# Duplicate found: Tr-no_0176.jpg is a duplicate of Tr-no_1175.jpg
# Duplicate found: Tr-no_1241.jpg is a duplicate of Tr-no_0565.jpg
# Duplicate found: Tr-no_0238.jpg is a duplicate of Tr-no_1146.jpg
# Duplicate found: Tr-no_0050.jpg is a duplicate of Tr-no_0346.jpg
# Duplicate found: Tr-no_1016.jpg is a duplicate of Tr-no_0158.jpg
# Duplicate found: Tr-no_0701.jpg is a duplicate of Tr-no_1123.jpg
# Duplicate found: Tr-no_0014.jpg is a duplicate of Tr-no_0013.jpg
# Duplicate found: Tr-no_0531.jpg is a duplicate of Tr-no_0674.jpg
# Duplicate found: Tr-no_0136.jpg is a duplicate of Tr-no_0118.jpg
# Duplicate found: Tr-no_0889.jpg is a duplicate of Tr-no_0178.jpg
# Duplicate found: Tr-no_0149.jpg is a duplicate of Tr-no_0143.jpg
# Duplicate found: Tr-no_1058.jpg is a duplicate of Tr-no_0017.jpg
# Duplicate found: Tr-no_0239.jpg is a duplicate of Tr-no_0234.jpg
# Duplicate found: Tr-no_0223.jpg is a duplicate of Tr-no_1101.jpg
# Duplicate found: Tr-no_0510.jpg is a duplicate of Tr-no_1489.jpg
# Duplicate found: Tr-no_1261.jpg is a duplicate of Tr-no_1197.jpg
# Duplicate found: Tr-no_0340.jpg is a duplicate of Tr-no_1153.jpg
# Duplicate found: Tr-no_0338.jpg is a duplicate of Tr-no_1084.jpg
# Duplicate found: Tr-no_0720.jpg is a duplicate of Tr-no_1554.jpg
# Duplicate found: Tr-no_1023.jpg is a duplicate of Tr-no_1479.jpg
# Duplicate found: Tr-no_0579.jpg is a duplicate of Tr-no_1197.jpg
# Duplicate found: Tr-no_1165.jpg is a duplicate of Tr-no_1531.jpg
# Duplicate found: Tr-no_0349.jpg is a duplicate of Tr-no_0964.jpg
# Duplicate found: Tr-no_1064.jpg is a duplicate of Tr-no_1006.jpg
# Duplicate found: Tr-no_0197.jpg is a duplicate of Tr-no_0276.jpg
# Duplicate found: Tr-no_0020.jpg is a duplicate of Tr-no_1006.jpg
# Duplicate found: Tr-no_0242.jpg is a duplicate of Tr-no_0150.jpg
# Duplicate found: Tr-no_1577.jpg is a duplicate of Tr-no_1508.jpg
# Duplicate found: Tr-no_0011.jpg is a duplicate of Tr-no_0012.jpg
# Duplicate found: Tr-no_0487.jpg is a duplicate of Tr-no_1482.jpg
# Duplicate found: Tr-no_0914.jpg is a duplicate of Tr-no_0185.jpg
# Duplicate found: Tr-no_0318.jpg is a duplicate of Tr-no_1170.jpg
# Duplicate found: Tr-no_0183.jpg is a duplicate of Tr-no_0973.jpg
# Duplicate found: Tr-no_0274.jpg is a duplicate of Tr-no_1150.jpg
# Duplicate found: Tr-no_0181.jpg is a duplicate of Tr-no_0099.jpg
# Duplicate found: Tr-no_0966.jpg is a duplicate of Tr-no_0323.jpg
# Duplicate found: Tr-no_0939.jpg is a duplicate of Tr-no_1034.jpg
# Duplicate found: Tr-no_0120.jpg is a duplicate of Tr-no_0368.jpg
# Duplicate found: Tr-no_0308.jpg is a duplicate of Tr-no_1164.jpg
# Duplicate found: Tr-no_0705.jpg is a duplicate of Tr-no_0178.jpg
# Duplicate found: Tr-no_1223.jpg is a duplicate of Tr-no_0674.jpg
# Duplicate found: Tr-no_0658.jpg is a duplicate of Tr-no_1482.jpg
# Duplicate found: Tr-no_0063.jpg is a duplicate of Tr-no_0334.jpg
# Duplicate found: Tr-no_0369.jpg is a duplicate of Tr-no_0131.jpg
# Duplicate found: Tr-no_1177.jpg is a duplicate of Tr-no_0973.jpg
# Duplicate found: Tr-no_1487.jpg is a duplicate of Tr-no_1461.jpg
# Duplicate found: Tr-no_0632.jpg is a duplicate of Tr-no_0452.jpg
# Duplicate found: Tr-no_0034.jpg is a duplicate of Tr-no_1078.jpg
# Duplicate found: Tr-no_0257.jpg is a duplicate of Tr-no_1096.jpg
# Duplicate found: Tr-no_1466.jpg is a duplicate of Tr-no_0511.jpg
# Duplicate found: Tr-no_0054.jpg is a duplicate of Tr-no_1091.jpg
# Duplicate found: Tr-no_1168.jpg is a duplicate of Tr-no_0316.jpg
# Duplicate found: Tr-no_1190.jpg is a duplicate of Tr-no_1255.jpg
# Duplicate found: Tr-no_0195.jpg is a duplicate of Tr-no_1130.jpg
# Duplicate found: Tr-no_0225.jpg is a duplicate of Tr-no_1126.jpg
# Duplicate found: Tr-no_1180.jpg is a duplicate of Tr-no_0178.jpg
# Duplicate found: Tr-no_0154.jpg is a duplicate of Tr-no_0237.jpg
# Duplicate found: Tr-no_0213.jpg is a duplicate of Tr-no_0341.jpg
# Duplicate found: Tr-no_0216.jpg is a duplicate of Tr-no_1060.jpg
# Duplicate found: Tr-no_1572.jpg is a duplicate of Tr-no_1507.jpg
# Duplicate found: Tr-no_0025.jpg is a duplicate of Tr-no_1067.jpg
# Duplicate found: Tr-no_0325.jpg is a duplicate of Tr-no_0336.jpg
# Duplicate found: Tr-no_0362.jpg is a duplicate of Tr-no_0328.jpg
# Duplicate found: Tr-noTr_0003.jpg is a duplicate of Tr-no_0994.jpg
# Duplicate found: Tr-no_0123.jpg is a duplicate of Tr-no_0118.jpg
# Duplicate found: Tr-no_0619.jpg is a duplicate of Tr-no_1392.jpg
# Duplicate found: Tr-no_1131.jpg is a duplicate of Tr-no_0012.jpg
# Duplicate found: Tr-no_1088.jpg is a duplicate of Tr-no_0373.jpg
# Duplicate found: Tr-no_0468.jpg is a duplicate of Tr-no_0845.jpg
# Duplicate found: Tr-no_0344.jpg is a duplicate of Tr-no_0148.jpg
# Duplicate found: Tr-no_1513.jpg is a duplicate of Tr-no_0452.jpg
# Duplicate found: Tr-no_0726.jpg is a duplicate of Tr-no_0535.jpg
# Duplicate found: Tr-no_1475.jpg is a duplicate of Tr-no_0799.jpg
# Duplicate found: Tr-no_0219.jpg is a duplicate of Tr-no_0193.jpg
# Duplicate found: Tr-no_0159.jpg is a duplicate of Tr-no_0111.jpg
# Duplicate found: Tr-no_0222.jpg is a duplicate of Tr-no_0148.jpg
# Duplicate found: Tr-no_1056.jpg is a duplicate of Tr-no_0015.jpg
# Duplicate found: Tr-no_0023.jpg is a duplicate of Tr-no_1066.jpg
# Duplicate found: Tr-no_0700.jpg is a duplicate of Tr-no_0551.jpg
# Duplicate found: Tr-no_1235.jpg is a duplicate of Tr-no_1175.jpg
# Duplicate found: Tr-no_0166.jpg is a duplicate of Tr-no_1119.jpg
# Duplicate found: Tr-no_0064.jpg is a duplicate of Tr-no_0336.jpg
# Duplicate found: Tr-no_1161.jpg is a duplicate of Tr-no_1002.jpg
# Duplicate found: Tr-no_0347.jpg is a duplicate of Tr-no_0373.jpg
# Duplicate found: Tr-no_0284.jpg is a duplicate of Tr-no_1002.jpg
# Duplicate found: Tr-no_1425.jpg is a duplicate of Tr-no_0439.jpg
# Duplicate found: Tr-no_1544.jpg is a duplicate of Tr-no_0719.jpg
# Duplicate found: Tr-no_0332.jpg is a duplicate of Tr-no_0224.jpg
# Duplicate found: Tr-no_1083.jpg is a duplicate of Tr-no_0220.jpg
# Duplicate found: Tr-no_0248.jpg is a duplicate of Tr-no_1144.jpg
# Duplicate found: Tr-no_1135.jpg is a duplicate of Tr-no_0234.jpg
# Duplicate found: Tr-no_1169.jpg is a duplicate of Tr-no_0317.jpg
# Duplicate found: Tr-no_0062.jpg is a duplicate of Tr-no_1159.jpg
# Duplicate found: Tr-no_0165.jpg is a duplicate of Tr-no_1118.jpg
# Duplicate found: Tr-no_1467.jpg is a duplicate of Tr-no_0743.jpg
# Duplicate found: Tr-no_1079.jpg is a duplicate of Tr-no_0035.jpg
# Duplicate found: Tr-no_0037.jpg is a duplicate of Tr-no_1081.jpg
# Duplicate found: Tr-no_0043.jpg is a duplicate of Tr-no_1162.jpg
# Duplicate found: Tr-no_1007.jpg is a duplicate of Tr-no_0300.jpg
# Duplicate found: Tr-no_1040.jpg is a duplicate of Tr-no_1130.jpg
# Duplicate found: Tr-no_0116.jpg is a duplicate of Tr-no_0130.jpg
# Duplicate found: Tr-no_0241.jpg is a duplicate of Tr-no_1137.jpg
# Duplicate found: Tr-no_0191.jpg is a duplicate of Tr-no_0279.jpg
# Duplicate found: Tr-no_1068.jpg is a duplicate of Tr-no_0026.jpg
# Duplicate found: Tr-no_0174.jpg is a duplicate of Tr-no_0189.jpg
# Duplicate found: Tr-no_1536.jpg is a duplicate of Tr-no_1315.jpg
# Duplicate found: Tr-no_0171.jpg is a duplicate of Tr-no_1129.jpg
# Duplicate found: Tr-no_1008.jpg is a duplicate of Tr-no_1044.jpg
# Duplicate found: Tr-no_0968.jpg is a duplicate of Tr-no_0102.jpg
# Duplicate found: Tr-no_0554.jpg is a duplicate of Tr-no_0828.jpg
# Duplicate found: Tr-no_1113.jpg is a duplicate of Tr-no_0158.jpg
# Duplicate found: Tr-no_0153.jpg is a duplicate of Tr-no_1108.jpg
# Duplicate found: Tr-no_0151.jpg is a duplicate of Tr-no_1106.jpg
# Duplicate found: Tr-no_1174.jpg is a duplicate of Tr-no_0326.jpg
# Duplicate found: Tr-no_1052.jpg is a duplicate of Tr-noTr_0007.jpg
# Duplicate found: Tr-no_0345.jpg is a duplicate of Tr-no_0985.jpg
# Duplicate found: Tr-no_1090.jpg is a duplicate of Tr-no_0053.jpg
# Duplicate found: Tr-no_0231.jpg is a duplicate of Tr-no_0012.jpg
# Duplicate found: Tr-no_1484.jpg is a duplicate of Tr-no_0565.jpg
# Duplicate found: Tr-no_1073.jpg is a duplicate of Tr-no_0032.jpg
# Duplicate found: Tr-no_1157.jpg is a duplicate of Tr-no_0960.jpg
# Duplicate found: Tr-no_1015.jpg is a duplicate of Tr-no_0185.jpg
# Duplicate found: Tr-no_0029.jpg is a duplicate of Tr-noTr_0005.jpg
# Duplicate found: Tr-no_1075.jpg is a duplicate of Tr-no_1107.jpg
# Duplicate found: Tr-no_0974.jpg is a duplicate of Tr-no_0334.jpg
# Duplicate found: Tr-no_1103.jpg is a duplicate of Tr-no_0346.jpg
# Duplicate found: Tr-no_0926.jpg is a duplicate of Tr-no_0560.jpg
# Duplicate found: Tr-no_0425.jpg is a duplicate of Tr-no_0722.jpg
# Duplicate found: Tr-no_1115.jpg is a duplicate of Tr-no_0160.jpg
# Duplicate found: Tr-no_1092.jpg is a duplicate of Tr-no_0112.jpg
# Duplicate found: Tr-no_0330.jpg is a duplicate of Tr-no_0971.jpg
# Duplicate found: Tr-no_1141.jpg is a duplicate of Tr-no_0179.jpg
# Duplicate found: Tr-no_1532.jpg is a duplicate of Tr-no_1224.jpg
# Duplicate found: Tr-no_0055.jpg is a duplicate of Tr-no_1039.jpg
# Duplicate found: Tr-no_0327.jpg is a duplicate of Tr-no_0970.jpg
# Duplicate found: Tr-no_0133.jpg is a duplicate of Tr-no_0370.jpg
# Duplicate found: Tr-no_1525.jpg is a duplicate of Tr-no_0614.jpg
# Duplicate found: Tr-no_0057.jpg is a duplicate of Tr-no_0324.jpg
# Duplicate found: Tr-no_1057.jpg is a duplicate of Tr-no_0016.jpg
# Duplicate found: Tr-no_0267.jpg is a duplicate of Tr-no_1146.jpg
# Duplicate found: Tr-no_0365.jpg is a duplicate of Tr-no_0368.jpg
# Duplicate found: Tr-no_0460.jpg is a duplicate of Tr-no_0625.jpg
# Duplicate found: Tr-no_0984.jpg is a duplicate of Tr-no_0324.jpg
# Duplicate found: Tr-no_1049.jpg is a duplicate of Tr-no_0788.jpg
# Duplicate found: Tr-no_0982.jpg is a duplicate of Tr-no_0224.jpg
# Duplicate found: Tr-no_0215.jpg is a duplicate of Tr-no_1050.jpg
# Duplicate found: Tr-no_0132.jpg is a duplicate of Tr-no_0130.jpg
# Duplicate found: Tr-no_1025.jpg is a duplicate of Tr-no_0565.jpg
# Duplicate found: Tr-no_0027.jpg is a duplicate of Tr-no_1193.jpg
# Duplicate found: Tr-no_1114.jpg is a duplicate of Tr-no_0111.jpg
# Duplicate found: Tr-no_1035.jpg is a duplicate of Tr-no_0707.jpg
# Duplicate found: Tr-no_0244.jpg is a duplicate of Tr-no_1139.jpg
# Duplicate found: Tr-no_0286.jpg is a duplicate of Tr-no_1004.jpg
# Duplicate found: Tr-no_0046.jpg is a duplicate of Tr-no_0967.jpg
# Duplicate found: Tr-no_1102.jpg is a duplicate of Tr-no_0182.jpg
# Duplicate found: Tr-no_0277.jpg is a duplicate of Tr-no_1152.jpg
# Duplicate found: Tr-no_0852.jpg is a duplicate of Tr-no_0960.jpg
# Duplicate found: Tr-no_0145.jpg is a duplicate of Tr-no_0182.jpg
# Duplicate found: Tr-no_1163.jpg is a duplicate of Tr-no_0304.jpg
# Duplicate found: Tr-no_1575.jpg is a duplicate of Tr-no_1363.jpg
# Duplicate found: Tr-no_0270.jpg is a duplicate of Tr-no_0264.jpg
# Duplicate found: Tr-no_1112.jpg is a duplicate of Tr-no_0139.jpg
# Duplicate found: Tr-no_0480.jpg is a duplicate of Tr-no_1218.jpg
# Duplicate found: Tr-no_0162.jpg is a duplicate of Tr-no_0972.jpg
# Duplicate found: Tr-no_0033.jpg is a duplicate of Tr-no_1077.jpg
# Duplicate found: Tr-no_0977.jpg is a duplicate of Tr-no_0328.jpg
# Duplicate found: Tr-no_1181.jpg is a duplicate of Tr-no_0341.jpg
# Duplicate found: Tr-no_0059.jpg is a duplicate of Tr-no_1173.jpg
# Duplicate found: Tr-no_0352.jpg is a duplicate of Tr-no_1089.jpg
# Duplicate found: Tr-no_1080.jpg is a duplicate of Tr-no_0036.jpg
# Duplicate found: Tr-no_0335.jpg is a duplicate of Tr-no_0394.jpg
# Duplicate found: Tr-no_0298.jpg is a duplicate of Tr-no_0012.jpg
# Duplicate found: Tr-no_0235.jpg is a duplicate of Tr-no_0279.jpg
# Duplicate found: Tr-no_0081.jpg is a duplicate of Tr-no_0076.jpg
# Duplicate found: Tr-no_1445.jpg is a duplicate of Tr-no_1338.jpg
# Duplicate found: Tr-no_0898.jpg is a duplicate of Tr-no_1128.jpg
# Duplicate found: Tr-no_0079.jpg is a duplicate of Tr-no_0074.jpg
# Duplicate found: Tr-no_1149.jpg is a duplicate of Tr-no_0264.jpg
# Duplicate found: Tr-no_1204.jpg is a duplicate of Tr-no_1563.jpg
# Duplicate found: Tr-no_1147.jpg is a duplicate of Tr-no_0042.jpg
# Duplicate found: Tr-no_0227.jpg is a duplicate of Tr-no_1128.jpg
# Duplicate found: Tr-no_0339.jpg is a duplicate of Tr-no_0981.jpg
# Duplicate found: Tr-no_0069.jpg is a duplicate of Tr-no_1084.jpg
# Duplicate found: Tr-no_1253.jpg is a duplicate of Tr-no_0496.jpg
# Duplicate found: Tr-no_0996.jpg is a duplicate of Tr-no_1127.jpg
# Duplicate found: Tr-no_1142.jpg is a duplicate of Tr-no_0247.jpg
# Duplicate found: Tr-no_1571.jpg is a duplicate of Tr-no_0625.jpg
# Duplicate found: Tr-no_1125.jpg is a duplicate of Tr-no_0170.jpg
# Duplicate found: Tr-no_1156.jpg is a duplicate of Tr-no_0281.jpg
# Duplicate found: Tr-no_0125.jpg is a duplicate of Tr-no_0368.jpg
# Duplicate found: Tr-no_1151.jpg is a duplicate of Tr-no_0276.jpg
# Duplicate found: Tr-noTr_0002.jpg is a duplicate of Tr-no_1059.jpg
# Duplicate found: Tr-no_1155.jpg is a duplicate of Tr-no_0280.jpg
# Duplicate found: Tr-no_0039.jpg is a duplicate of Tr-no_1082.jpg
# Duplicate found: Tr-no_0218.jpg is a duplicate of Tr-no_1071.jpg
# Duplicate found: Tr-no_0052.jpg is a duplicate of Tr-no_1089.jpg
# Duplicate found: Tr-no_1100.jpg is a duplicate of Tr-no_0139.jpg
# Duplicate found: Tr-no_0268.jpg is a duplicate of Tr-no_0224.jpg
# Duplicate found: Tr-no_0962.jpg is a duplicate of Tr-no_0190.jpg
# Duplicate found: Tr-no_0980.jpg is a duplicate of Tr-no_0192.jpg
# Duplicate found: Tr-no_0187.jpg is a duplicate of Tr-no_0185.jpg
# Duplicate found: Tr-no_0978.jpg is a duplicate of Tr-no_0394.jpg
# Duplicate found: Tr-no_1116.jpg is a duplicate of Tr-no_0161.jpg
# Duplicate found: Tr-no_0028.jpg is a duplicate of Tr-no_1070.jpg
# Duplicate found: Tr-no_0350.jpg is a duplicate of Tr-no_0224.jpg
# Duplicate found: Tr-no_0091.jpg is a duplicate of Tr-no_0985.jpg
# Duplicate found: Tr-no_1095.jpg is a duplicate of Tr-no_0131.jpg
# Duplicate found: Tr-no_1448.jpg is a duplicate of Tr-no_1520.jpg
# Duplicate found: Tr-no_0384.jpg is a duplicate of Tr-no_0989.jpg
# Duplicate found: Tr-no_0319.jpg is a duplicate of Tr-no_1171.jpg
# Duplicate found: Tr-no_0205.jpg is a duplicate of Tr-no_1027.jpg
# Duplicate found: Tr-no_0135.jpg is a duplicate of Tr-no_1096.jpg
# Duplicate found: Tr-no_0051.jpg is a duplicate of Tr-no_0373.jpg
# Duplicate found: Tr-no_1117.jpg is a duplicate of Tr-no_0150.jpg
# Duplicate found: Tr-no_1063.jpg is a duplicate of Tr-no_0018.jpg
# Duplicate found: Tr-no_0113.jpg is a duplicate of Tr-no_1093.jpg
# Duplicate found: Tr-no_0364.jpg is a duplicate of Tr-no_0979.jpg
# Duplicate found: Tr-no_1183.jpg is a duplicate of Tr-no_0336.jpg
# Duplicate found: Tr-no_0128.jpg is a duplicate of Tr-no_0137.jpg
# Duplicate found: Tr-no_0229.jpg is a duplicate of Tr-no_1130.jpg
# Duplicate found: Tr-no_1541.jpg is a duplicate of Tr-no_1254.jpg
# Duplicate found: Tr-no_1038.jpg is a duplicate of Tr-no_0741.jpg
# Duplicate found: Tr-no_1003.jpg is a duplicate of Tr-noTr_0005.jpg
# Duplicate found: Tr-no_1562.jpg is a duplicate of Tr-no_1499.jpg
# Duplicate found: Tr-no_0245.jpg is a duplicate of Tr-no_1140.jpg
# Duplicate found: Tr-no_0200.jpg is a duplicate of Tr-no_0194.jpg
# Duplicate found: Tr-no_1178.jpg is a duplicate of Tr-no_0202.jpg
# Duplicate found: Tr-no_0169.jpg is a duplicate of Tr-no_1123.jpg
# Duplicate found: Tr-no_0459.jpg is a duplicate of Tr-no_1302.jpg
# Duplicate found: Tr-no_1521.jpg is a duplicate of Tr-no_0607.jpg
# Duplicate found: Tr-no_1094.jpg is a duplicate of Tr-no_0124.jpg
# Duplicate found: Tr-no_1160.jpg is a duplicate of Tr-no_1041.jpg
# Duplicate found: Tr-no_1317.jpg is a duplicate of Tr-no_0845.jpg
# Duplicate found: Tr-no_0144.jpg is a duplicate of Tr-no_1255.jpg
# Duplicate found: Tr-no_0024.jpg is a duplicate of Tr-no_0012.jpg
# Duplicate found: Tr-no_0180.jpg is a duplicate of Tr-no_0324.jpg
# Duplicate found: Tr-no_1281.jpg is a duplicate of Tr-no_1379.jpg
# Duplicate found: Tr-no_0969.jpg is a duplicate of Tr-no_0353.jpg
# Duplicate found: Tr-no_1046.jpg is a duplicate of Tr-no_0143.jpg
# Duplicate found: Tr-no_1518.jpg is a duplicate of Tr-no_0403.jpg
# Duplicate found: Tr-no_1138.jpg is a duplicate of Tr-no_0178.jpg
# Duplicate found: Tr-no_0689.jpg is a duplicate of Tr-no_0954.jpg
# Duplicate found: Tr-no_1085.jpg is a duplicate of Tr-no_1123.jpg
# Duplicate found: Tr-no_0122.jpg is a duplicate of Tr-no_0119.jpg
# Duplicate found: Tr-no_1009.jpg is a duplicate of Tr-noTr_0005.jpg
# Duplicate found: Tr-no_0283.jpg is a duplicate of Tr-no_1158.jpg
# Duplicate found: Tr-no_1167.jpg is a duplicate of Tr-no_0175.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/meningioma/Tr-me_0366.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/meningioma/Tr-me_0249.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/meningioma/Tr-me_0616.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/meningioma/Tr-me_0238.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/meningioma/Tr-me_0175.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/meningioma/Tr-me_0176.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0676.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0518.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0321.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0160.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0108.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0169.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0157.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0526.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0342.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0226.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0527.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/pituitary/Tr-pi_0516.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0117.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0226.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0056.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0291.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0164.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1538.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0077.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0711.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1500.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-noTr_0006.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1098.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0331.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1045.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1110.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0031.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1055.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1069.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1026.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1042.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1053.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1182.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1490.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0236.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0282.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0142.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1303.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1104.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0399.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0714.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0766.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0423.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0366.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0152.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1179.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0313.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0199.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0073.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0168.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0294.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0140.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1256.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0176.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1241.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0238.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0050.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1016.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0701.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0014.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0531.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0136.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0889.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0149.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1058.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0239.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0223.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0510.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1261.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0340.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0338.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0720.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1023.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0579.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1165.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0349.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1064.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0197.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0020.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0242.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1577.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0011.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0487.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0914.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0318.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0183.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0274.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0181.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0966.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0939.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0120.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0308.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0705.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1223.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0658.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0063.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0369.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1177.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1487.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0632.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0034.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0257.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1466.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0054.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1168.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1190.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0195.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0225.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1180.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0154.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0213.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0216.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1572.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0025.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0325.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0362.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-noTr_0003.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0123.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0619.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1131.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1088.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0468.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0344.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1513.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0726.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1475.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0219.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0159.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0222.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1056.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0023.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0700.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1235.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0166.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0064.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1161.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0347.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0284.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1425.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1544.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0332.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1083.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0248.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1135.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1169.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0062.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0165.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1467.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1079.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0037.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0043.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1007.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1040.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0116.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0241.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0191.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1068.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0174.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1536.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0171.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1008.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0968.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0554.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1113.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0153.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0151.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1174.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1052.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0345.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1090.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0231.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1484.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1073.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1157.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1015.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0029.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1075.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0974.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1103.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0926.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0425.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1115.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1092.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0330.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1141.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1532.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0055.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0327.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0133.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1525.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0057.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1057.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0267.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0365.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0460.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0984.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1049.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0982.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0215.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0132.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1025.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0027.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1114.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1035.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0244.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0286.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0046.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1102.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0277.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0852.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0145.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1163.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1575.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0270.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1112.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0480.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0162.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0033.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0977.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1181.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0059.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0352.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1080.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0335.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0298.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0235.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0081.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1445.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0898.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0079.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1149.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1204.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1147.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0227.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0339.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0069.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1253.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0996.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1142.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1571.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1125.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1156.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0125.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1151.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-noTr_0002.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1155.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0039.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0218.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0052.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1100.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0268.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0962.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0980.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0187.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0978.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1116.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0028.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0350.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0091.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1095.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1448.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0384.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0319.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0205.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0135.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0051.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1117.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1063.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0113.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0364.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1183.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0128.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0229.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1541.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1038.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1003.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1562.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0245.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0200.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1178.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0169.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0459.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1521.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1094.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1160.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1317.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0144.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0024.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0180.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1281.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0969.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1046.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1518.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1138.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0689.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1085.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0122.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1009.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_0283.jpg
# Deleted duplicate image: /content/BrainTumour_Dataset/Training/notumor/Tr-no_1167.jpg

# %%
def plot_class_distribution(data_dir, categories):
    class_counts = {}
    for category in categories:
        class_counts[category] = len(os.listdir(os.path.join(data_dir, category)))

    plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'green', 'red', 'purple'])
    plt.title("Class Distribution After Removing Duplicates")
    plt.xlabel("Tumor Category")
    plt.ylabel("Number of Images")
    plt.show()

plot_class_distribution(data_dir, categories)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense,
                                     Dropout, BatchNormalization)
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# Define image size and other parameters
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 20

# Paths
train_dir = '/content/BrainTumour_Dataset/Training/'
# If you have a separate validation directory, define it here. Otherwise, we'll split the training data.
# val_dir = '/content/BrainTumour_Dataset/Validation/'

# %%
# ImageDataGenerator for training with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,              # Normalize pixel values
    rotation_range=30,           # Rotate images by 30 degrees
    width_shift_range=0.2,       # Horizontal shift
    height_shift_range=0.2,      # Vertical shift
    shear_range=0.2,             # Shear transformation
    zoom_range=0.2,              # Zoom in/out
    horizontal_flip=True,        # Randomly flip images
    fill_mode='nearest',         # Fill missing pixels
    validation_split=0.2          # Split 20% of data for validation
)

# ImageDataGenerator for validation (only rescaling)
validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# Create training generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',            # Set as training data
    shuffle=True,
    seed=42
)

# Create validation generator
validation_generator = validation_datagen.flow_from_directory(
    train_dir,                    # Same directory as training data
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',          # Set as validation data
    shuffle=True,
    seed=42
)

# %%
def build_basic_cnn(input_shape=(224, 224, 1), num_classes=4):
    model = Sequential()

    # First Convolutional Block
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))

    # Second Convolutional Block
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))

    # Third Convolutional Block
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))

    # Flatten and Fully Connected Layers
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))  # To prevent overfitting
    model.add(Dense(num_classes, activation='softmax'))

    return model

# Since the images are grayscale, set input_shape accordingly
input_shape = (IMG_SIZE, IMG_SIZE, 3)  # Grayscale
model = build_basic_cnn(input_shape=input_shape, num_classes=4)
model.summary()

# %%
# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE
)

# %%
# Train the model


# Plot the training and validation accuracy and loss
def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 8))

    # Plot Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.tight_layout()
    plt.show()

# Call the function to plot
plot_training_history(history)

# %%
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, LeakyReLU, Flatten


class Discriminator(object):
    def __init__(self, input_shape):
        inputs = Input(input_shape)
        conv1 = Conv2D(64, (5, 5), padding='same')(inputs)
        conv1 = LeakyReLU(0.2)(conv1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
        conv2 = Conv2D(128, (5, 5), padding='same')(pool1)
        conv2 = LeakyReLU(0.2)(conv2)
        pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
        fc1 = Flatten()(pool2)
        fc1 = Dense(1)(fc1)
        outputs = Activation('sigmoid')(fc1)

        self.model = Model(inputs=[inputs], outputs=[outputs])

    def get_model(self):
        return self.model

# %%
import numpy as np
import os
import cv2
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, BatchNormalization, LeakyReLU, Reshape, Conv2DTranspose, Flatten, Embedding, multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Concatenate
from keras.callbacks import EarlyStopping


# Load and preprocess the dataset
def load_data(data_dir):
    images = []
    labels = []
    label_dict = {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

    for label_name in os.listdir(data_dir):
        label_dir = os.path.join(data_dir, label_name)
        for img_file in os.listdir(label_dir):
            img_path = os.path.join(label_dir, img_file)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (64, 64))  # Resizing to 64x64
            images.append(img)
            labels.append(label_dict[label_name])

    images = np.array(images).astype('float32') / 255.0  # Normalize
    labels = np.array(labels)
    return images, labels

# Load data
data_dir = '/content/BrainTumour_Dataset/Training/'
x_train, y_train = load_data(data_dir)

# Add a channel dimension for grayscale images
x_train = np.expand_dims(x_train, axis=-1)
num_classes = 4
input_dim = 100  # Noise dimension

# Build Conditional Generator Model
def build_generator(input_dim, num_classes):
    noise = Input(shape=(input_dim,))
    label = Input(shape=(1,), dtype='int32')

    label_embedding = Embedding(num_classes, input_dim, input_length=1)(label)
    label_embedding = Flatten()(label_embedding)

    model_input = multiply([noise, label_embedding])

    model = Sequential()
    model.add(Dense(256 * 8 * 8, input_dim=input_dim))
    model.add(Reshape((8, 8, 256)))
    model.add(Conv2DTranspose(128, (5,5), strides=(2,2), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(0.2))

    model.add(Conv2DTranspose(64, (5,5), strides=(2,2), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(0.2))

    model.add(Conv2DTranspose(1, (5,5), strides=(2,2), padding='same', activation='tanh'))

    img = model(model_input)

    return Model([noise, label], img)

# Build Conditional Discriminator Model
def build_discriminator(img_shape, num_classes):
    img = Input(shape=img_shape)
    label = Input(shape=(1,), dtype='int32')

    label_embedding = Embedding(num_classes, np.prod(img_shape))(label)
    label_embedding = Flatten()(label_embedding)
    label_embedding = Reshape(img_shape)(label_embedding)

    model_input = Concatenate(axis=-1)([img, label_embedding])

    model = Sequential()
    model.add(Conv2D(64, (5,5), strides=(2,2), padding='same', input_shape=(64,64,2)))
    model.add(LeakyReLU(0.2))

    model.add(Conv2D(128, (5,5), strides=(2,2), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(0.2))

    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    validity = model(model_input)

    return Model([img, label], validity)

# Define input dimensions and image shape
img_shape = (64, 64, 1)  # Image size for grayscale MRI images

# Build the Generator and Discriminator Models
generator = build_generator(input_dim, num_classes)
discriminator = build_discriminator(img_shape, num_classes)

# Compile the Discriminator with a lower learning rate and gradient clipping
opt = Adam(learning_rate=0.0001, beta_1=0.5)  # Lower learning rate
discriminator.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# The combined model
noise = Input(shape=(input_dim,))
label = Input(shape=(1,))
gen_img = generator([noise, label])
discriminator.trainable = False
validity = discriminator([gen_img, label])
combined = Model([noise, label], validity)
combined.compile(loss='binary_crossentropy', optimizer=opt)

# Training
def train(epochs, batch_size=32, save_interval=50):
    half_batch = batch_size // 2

    for epoch in range(epochs):

        # Train the Discriminator
        idx = np.random.randint(0, x_train.shape[0], half_batch)
        real_imgs = x_train[idx]
        labels_real = y_train[idx]

        noise = np.random.normal(0, 1, (half_batch, input_dim))
        labels_fake = np.random.randint(0, num_classes, half_batch)
        gen_imgs = generator.predict([noise, labels_fake])

        d_loss_real = discriminator.train_on_batch([real_imgs, labels_real], np.ones((half_batch, 1)))
        d_loss_fake = discriminator.train_on_batch([gen_imgs, labels_fake], np.zeros((half_batch, 1)))
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train the Generator
        noise = np.random.normal(0, 1, (batch_size, input_dim))
        labels = np.random.randint(0, num_classes, batch_size)
        valid_y = np.array([1] * batch_size)
        g_loss = combined.train_on_batch([noise, labels], valid_y)

        # Print progress
        print(f"{epoch}/{epochs}, D loss: {d_loss[0]}, G loss: {g_loss}")

        # Save generated images at intervals
        if epoch % save_interval == 0:
            save_imgs(epoch)

# Save generated images
def save_imgs(epoch):
    noise = np.random.normal(0, 1, (25, input_dim))
    labels = np.random.randint(0, num_classes, 25)
    gen_imgs = generator.predict([noise, labels])

    # Rescale images 0 - 1
    gen_imgs = 0.5 * gen_imgs + 0.5

    for i in range(25):
        cv2.imwrite(f"images/gen_{epoch}_{i}.png", gen_imgs[i] * 255)

# Train the model
train(epochs=10000, batch_size=32, save_interval=200)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import save_image
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os

# Set random seed for reproducibility
torch.manual_seed(42)

# Hyperparameters
latent_dim = 100
image_size = 64
batch_size = 64
num_epochs = 50
lr = 0.0002
beta1 = 0.5

# Set your dataset path here
dataset_path = "/content/BrainTumour_Dataset/Training/notumor"

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data preprocessing
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Custom Dataset class
class NoTumorDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.file_list = [f for f in os.listdir(root_dir) if f.endswith('.jpg') or f.endswith('.png')]

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.file_list[idx])
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image

# Function to load dataset
def load_dataset(data_path):
    dataset = NoTumorDataset(root_dir=data_path, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    return dataloader

# Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, 512, 4, 1, 0, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(True),
            nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, input):
        return self.main(input)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, 4, 2, 1, bias=False),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(512, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input).view(-1)

# Function to train the GAN
def train_gan(dataloader):
    netG = Generator().to(device)
    netD = Discriminator().to(device)

    criterion = nn.BCELoss()
    optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
    optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

    for epoch in range(num_epochs):
        for i, real_images in enumerate(dataloader):
            batch_size = real_images.size(0)
            real_images = real_images.to(device)

            # Train Discriminator
            netD.zero_grad()
            label = torch.full((batch_size,), 1.0, device=device)
            output = netD(real_images)
            errD_real = criterion(output, label)
            errD_real.backward()

            noise = torch.randn(batch_size, latent_dim, 1, 1, device=device)
            fake_images = netG(noise)
            label.fill_(0.0)
            output = netD(fake_images.detach())
            errD_fake = criterion(output, label)
            errD_fake.backward()

            errD = errD_real + errD_fake
            optimizerD.step()

            # Train Generator
            netG.zero_grad()
            label.fill_(1.0)
            output = netD(fake_images)
            errG = criterion(output, label)
            errG.backward()
            optimizerG.step()

            if i % 100 == 0:
                print(f'[{epoch}/{num_epochs}][{i}/{len(dataloader)}] Loss_D: {errD.item():.4f} Loss_G: {errG.item():.4f}')

        # Save generated images
        with torch.no_grad():
            fake = netG(torch.randn(64, latent_dim, 1, 1, device=device)).detach().cpu()
            save_image(fake, f'fake_images_epoch_{epoch}.png', normalize=True)

    return netG, netD

# Function to compare real and generated images
def compare_images(real_images, fake_images):
    plt.figure(figsize=(15, 8))
    plt.subplot(1, 2, 1)
    plt.title("Real Images")
    plt.imshow(torchvision.utils.make_grid(real_images[:64], normalize=True).permute(1, 2, 0))
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title("Generated Images")
    plt.imshow(torchvision.utils.make_grid(fake_images[:64], normalize=True).permute(1, 2, 0))
    plt.axis('off')

    plt.show()

# Main execution
if __name__ == "__main__":
    # Load the dataset
    dataloader = load_dataset(dataset_path)

    # Train the GAN
    netG, netD = train_gan(dataloader)

    # Generate and compare images
    real_batch = next(iter(dataloader))
    with torch.no_grad():
        fake_images = netG(torch.randn(64, latent_dim, 1, 1, device=device)).detach().cpu()
    compare_images(real_batch, fake_images)

    # Print generated images
    print("Generated Images:")
    torchvision.utils.print_image(fake_images[0])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os

# Set random seed for reproducibility
torch.manual_seed(42)

# Hyperparameters
latent_dim = 100
image_size = 64
batch_size = 64
num_epochs = 50
lr = 0.0002
beta1 = 0.5

# Set your dataset path here
dataset_path = "/content/BrainTumour_Dataset/Training/notumor"

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data preprocessing
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Custom Dataset class
class NoTumorDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.file_list = [f for f in os.listdir(root_dir) if f.endswith('.jpg') or f.endswith('.png')]

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.file_list[idx])
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image

# Function to load dataset
def load_dataset(data_path):
    dataset = NoTumorDataset(root_dir=data_path, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    return dataloader

# Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, 512, 4, 1, 0, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(True),
            nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, input):
        return self.main(input)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, 4, 2, 1, bias=False),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(512, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input).view(-1)

# Function to train the GAN
def train_gan(dataloader):
    netG = Generator().to(device)
    netD = Discriminator().to(device)

    criterion = nn.BCELoss()
    optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
    optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

    for epoch in range(num_epochs):
        for i, real_images in enumerate(dataloader):
            batch_size = real_images.size(0)
            real_images = real_images.to(device)

            # Train Discriminator
            netD.zero_grad()
            label = torch.full((batch_size,), 1.0, device=device)
            output = netD(real_images)
            errD_real = criterion(output, label)
            errD_real.backward()

            noise = torch.randn(batch_size, latent_dim, 1, 1, device=device)
            fake_images = netG(noise)
            label.fill_(0.0)
            output = netD(fake_images.detach())
            errD_fake = criterion(output, label)
            errD_fake.backward()

            errD = errD_real + errD_fake
            optimizerD.step()

            # Train Generator
            netG.zero_grad()
            label.fill_(1.0)
            output = netD(fake_images)
            errG = criterion(output, label)
            errG.backward()
            optimizerG.step()

            if i % 100 == 0:
                print(f'[{epoch}/{num_epochs}][{i}/{len(dataloader)}] Loss_D: {errD.item():.4f} Loss_G: {errG.item():.4f}')

        # Save generated images
        with torch.no_grad():
            fake = netG(torch.randn(64, latent_dim, 1, 1, device=device)).detach().cpu()
            save_image(fake, f'fake_images_epoch_{epoch}.png', normalize=True)

    return netG, netD

# Function to compare real and generated images
def compare_images(real_images, fake_images):
    plt.figure(figsize=(15, 8))
    plt.subplot(1, 2, 1)
    plt.title("Real Images")
    plt.imshow(make_grid(real_images[:64], normalize=True).permute(1, 2, 0))
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title("Generated Images")
    plt.imshow(make_grid(fake_images[:64], normalize=True).permute(1, 2, 0))
    plt.axis('off')

    plt.show()

# Main execution
if __name__ == "__main__":
    # Load the dataset
    dataloader = load_dataset(dataset_path)

    # Train the GAN
    netG, netD = train_gan(dataloader)

    # Generate and compare images
    real_batch = next(iter(dataloader))
    with torch.no_grad():
        fake_images = netG(torch.randn(64, latent_dim, 1, 1, device=device)).detach().cpu()
    compare_images(real_batch, fake_images)

    # Display a single generated image
    print("Generated Image:")
    plt.imshow(fake_images[0].permute(1, 2, 0))
    plt.axis('off')
    plt.show()

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split

def load_and_preprocess_images(data_dir, target_size=(256, 256)):
    images = []
    for img_name in os.listdir(data_dir):
        if img_name.endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(data_dir, img_name)
            img = load_img(img_path, color_mode='grayscale', target_size=target_size)
            img_array = img_to_array(img)
            images.append(img_array)

    return np.array(images)

def normalize_images(images):
    # Normalize to [-1, 1] range
    return (images / 127.5) - 1

def create_datasets(images, batch_size=32, validation_split=0.2):
    # Split the data into training and validation sets
    train_images, val_images = train_test_split(images, test_size=validation_split, random_state=42)

    # Create TensorFlow datasets
    train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(1000).batch(batch_size)
    val_dataset = tf.data.Dataset.from_tensor_slices(val_images).batch(batch_size)

    return train_dataset, val_dataset

def preprocess_mri_dataset(data_dir, target_size=(256, 256), batch_size=32, validation_split=0.2):
    # Load and preprocess images
    images = load_and_preprocess_images(data_dir, target_size)

    # Normalize images
    normalized_images = normalize_images(images)

    # Create datasets
    train_dataset, val_dataset = create_datasets(normalized_images, batch_size, validation_split)

    return train_dataset, val_dataset

# Example usage
if __name__ == "__main__":
    data_dir = "/content/BrainTumour_Dataset/Training/notumor"
    train_dataset, val_dataset = preprocess_mri_dataset(data_dir)

    print("Training dataset:", train_dataset)
    print("Validation dataset:", val_dataset)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
import numpy as np
import matplotlib.pyplot as plt

def build_generator(latent_dim, output_shape):
    model = models.Sequential([
        layers.Dense(16 * 16 * 256, input_dim=latent_dim),
        layers.Reshape((16, 16, 256)),
        layers.Conv2DTranspose(128, kernel_size=4, strides=2, padding='same'),
        layers.LeakyReLU(alpha=0.2),
        layers.BatchNormalization(),
        layers.Conv2DTranspose(64, kernel_size=4, strides=2, padding='same'),
        layers.LeakyReLU(alpha=0.2),
        layers.BatchNormalization(),
        layers.Conv2DTranspose(32, kernel_size=4, strides=2, padding='same'),
        layers.LeakyReLU(alpha=0.2),
        layers.BatchNormalization(),
        layers.Conv2DTranspose(16, kernel_size=4, strides=2, padding='same'),
        layers.LeakyReLU(alpha=0.2),
        layers.BatchNormalization(),
        layers.Conv2DTranspose(1, kernel_size=4, strides=1, padding='same', activation='tanh')
    ])
    return model

def build_discriminator(input_shape):
    model = models.Sequential([
        layers.Conv2D(16, kernel_size=4, strides=2, padding='same', input_shape=input_shape),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.3),
        layers.Conv2D(32, kernel_size=4, strides=2, padding='same'),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.3),
        layers.Conv2D(64, kernel_size=4, strides=2, padding='same'),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.3),
        layers.Conv2D(128, kernel_size=4, strides=2, padding='same'),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.3),
        layers.Conv2D(256, kernel_size=4, strides=2, padding='same'),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.3),
        layers.Flatten(),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

class GAN(models.Model):
    def __init__(self, latent_dim, input_shape):
        super(GAN, self).__init__()
        self.latent_dim = latent_dim
        self.generator = build_generator(latent_dim, input_shape)
        self.discriminator = build_discriminator(input_shape)

    def compile(self, g_optimizer, d_optimizer, loss_fn):
        super(GAN, self).compile()
        self.g_optimizer = g_optimizer
        self.d_optimizer = d_optimizer
        self.loss_fn = loss_fn

    def train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]
        latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))

        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            generated_images = self.generator(latent_vectors, training=True)

            real_output = self.discriminator(real_images, training=True)
            fake_output = self.discriminator(generated_images, training=True)

            gen_loss = self.loss_fn(tf.ones_like(fake_output), fake_output)
            disc_loss = self.loss_fn(tf.ones_like(real_output), real_output) + \
                        self.loss_fn(tf.zeros_like(fake_output), fake_output)

        gradients_of_generator = gen_tape.gradient(gen_loss, self.generator.trainable_variables)
        gradients_of_discriminator = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)

        self.g_optimizer.apply_gradients(zip(gradients_of_generator, self.generator.trainable_variables))
        self.d_optimizer.apply_gradients(zip(gradients_of_discriminator, self.discriminator.trainable_variables))

        return {"d_loss": disc_loss, "g_loss": gen_loss}

def train_gan(gan, dataset, epochs, batch_size):
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}/{epochs}")
        for batch in dataset:
            gan.train_step(batch)

        # Generate and save sample images
        if (epoch + 1) % 10 == 0:
            generate_and_save_images(gan, epoch + 1)

def generate_and_save_images(gan, epoch):
    test_input = tf.random.normal([16, gan.latent_dim])
    generated_images = gan.generator(test_input, training=False)

    fig = plt.figure(figsize=(4, 4))
    for i in range(16):
        plt.subplot(4, 4, i + 1)
        plt.imshow(generated_images[i, :, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off')
    plt.savefig(f'generated_images_epoch_{epoch}.png')
    plt.close()

# Hyperparameters
latent_dim = 100
input_shape = (256, 256, 1)
batch_size = 32
epochs = 100
learning_rate = 0.0002
beta_1 = 0.5

# Create and compile the GAN
gan = GAN(latent_dim, input_shape)
gan.compile(
    g_optimizer=optimizers.Adam(learning_rate=learning_rate, beta_1=beta_1),
    d_optimizer=optimizers.Adam(learning_rate=learning_rate, beta_1=beta_1),
    loss_fn=tf.keras.losses.BinaryCrossentropy(from_logits=False)
)

# Assuming you have already preprocessed your dataset
# train_dataset = ...

# Train the GAN
train_gan(gan, train_dataset, epochs, batch_size)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def get_generator_input_shape(generator):
    # Get the input shape of the generator
    if hasattr(generator, 'input_shape'):
        input_shape = generator.input_shape
    else:
        # If the model doesn't have an input_shape attribute, get it from the first layer
        input_shape = generator.layers[0].input_shape

    if isinstance(input_shape, list):
        input_shape = input_shape[0]

    # Remove the batch size dimension if it's None
    if input_shape[0] is None:
        input_shape = input_shape[1:]

    return input_shape

def generate_images_in_batches(generator, num_images=1000, batch_size=32):
    input_shape = get_generator_input_shape(generator)
    latent_dim = np.prod(input_shape)  # Calculate total number of elements
    num_batches = (num_images + batch_size - 1) // batch_size
    generated_images = []
    for _ in range(num_batches):
        batch_size = min(batch_size, num_images - len(generated_images))
        latent_vectors = tf.random.normal(shape=(batch_size, latent_dim))
        # Reshape latent vectors to match the input shape expected by the generator
        reshaped_vectors = tf.reshape(latent_vectors, (batch_size,) + input_shape)
        batch_images = generator(reshaped_vectors, training=False)
        generated_images.append(batch_images)
        if len(generated_images) * batch_size >= num_images:
            break
    return tf.concat(generated_images, axis=0)[:num_images]

def visualize_generated_images(generated_images, num_images=25):
    fig, axes = plt.subplots(5, 5, figsize=(15, 15))
    for i, ax in enumerate(axes.flat):
        if i < num_images:
            ax.imshow(generated_images[i, :, :, 0] * 0.5 + 0.5, cmap='gray')
        ax.axis('off')
    plt.tight_layout()
    plt.savefig('generated_images.png')
    plt.close()

def interpolate_latent_space(generator, num_steps=10):
    input_shape = get_generator_input_shape(generator)
    latent_dim = np.prod(input_shape)
    start_vector = tf.random.normal(shape=(1, latent_dim))
    end_vector = tf.random.normal(shape=(1, latent_dim))

    alphas = np.linspace(0, 1, num_steps)
    interpolated_vectors = tf.convert_to_tensor(
        [(1 - alpha) * start_vector + alpha * end_vector for alpha in alphas]
    )
    # Reshape interpolated vectors
    interpolated_vectors = tf.reshape(interpolated_vectors, (num_steps,) + input_shape)

    interpolated_images = generator(interpolated_vectors, training=False)

    fig, axes = plt.subplots(1, num_steps, figsize=(20, 4))
    for i, ax in enumerate(axes):
        ax.imshow(interpolated_images[i, :, :, 0] * 0.5 + 0.5, cmap='gray')
        ax.axis('off')
    plt.tight_layout()
    plt.savefig('latent_space_interpolation.png')
    plt.close()

def visualize_latent_space(generator, num_samples=1000):
    input_shape = get_generator_input_shape(generator)
    latent_dim = np.prod(input_shape)
    latent_vectors = tf.random.normal(shape=(num_samples, latent_dim))
    tsne = TSNE(n_components=2, random_state=42)
    latent_2d = tsne.fit_transform(latent_vectors)

    plt.figure(figsize=(10, 10))
    plt.scatter(latent_2d[:, 0], latent_2d[:, 1], alpha=0.5)
    plt.title('t-SNE visualization of latent space')
    plt.savefig('latent_space_tsne.png')
    plt.close()

def total_variation(images):
    pixel_dif1 = images[:, 1:, :, :] - images[:, :-1, :, :]
    pixel_dif2 = images[:, :, 1:, :] - images[:, :, :-1, :]
    total_var = tf.reduce_sum(tf.abs(pixel_dif1)) + tf.reduce_sum(tf.abs(pixel_dif2))
    return total_var / tf.cast(tf.reduce_prod(tf.shape(images)), tf.float32)

def calculate_fid(real_images, generated_images):
    # This is a simplified FID calculation and should be replaced with a proper implementation
    real_mean = tf.reduce_mean(real_images, axis=0)
    generated_mean = tf.reduce_mean(generated_images, axis=0)
    return tf.reduce_mean(tf.square(real_mean - generated_mean))

def post_training_analysis(gan, train_dataset, num_images=1000, batch_size=32):
    # Generate images in batches
    generated_images = generate_images_in_batches(gan.generator, num_images, batch_size)

    # Visualize generated images
    visualize_generated_images(generated_images[:25])

    # Interpolate in latent space
    interpolate_latent_space(gan.generator)

    # Visualize latent space
    visualize_latent_space(gan.generator, num_samples=1000)

    # Evaluate image quality
    tv_score = total_variation(generated_images[:100])  # Calculate TV score for first 100 images
    print(f"Total Variation score: {tv_score}")

    # Calculate FID score
    real_images = next(iter(train_dataset))  # Get a batch of real images from the training dataset
    fid_score = calculate_fid(real_images, generated_images[:len(real_images)])
    print(f"FID score (simplified): {fid_score}")

# Assuming you have your trained GAN model and train_dataset
# gan = ...  # Your trained GAN model
# train_dataset = ...  # Your training dataset

# Run post-training analysis
post_training_analysis(gan, train_dataset, num_images=1000, batch_size=32)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim
from scipy.ndimage import gaussian_filter

def generate_and_visualize_images(generator, num_images=16):
    latent_dim = generator.input_shape[1]
    noise = tf.random.normal([num_images, latent_dim])
    generated_images = generator(noise, training=False)

    fig = plt.figure(figsize=(4, 4))
    for i in range(num_images):
        plt.subplot(4, 4, i + 1)
        plt.imshow(generated_images[i, :, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.savefig('generated_brain_mri.png')
    plt.close()
    return generated_images
  generated_images
