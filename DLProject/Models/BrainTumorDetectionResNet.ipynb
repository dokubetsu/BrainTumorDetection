# %%
import shutil
import os


source_dir = '/kaggle/input/brain-tumor-mri-dataset/Training'
dest_dir = '/kaggle/working/brain-tumor-mri-dataset/Training'


shutil.copytree(source_dir, dest_dir)
# Out:
# '/kaggle/working/brain-tumor-mri-dataset/Training'

# %%
source_dir_test = '/kaggle/input/brain-tumor-mri-dataset/Testing'
dest_dir_test = '/kaggle/working/brain-tumor-mri-dataset/Testing'
shutil.copytree(source_dir_test, dest_dir_test)
# Out:
# '/kaggle/working/brain-tumor-mri-dataset/Testing'

# %%
os.listdir(dest_dir)
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import hashlib

def dhash(image, hash_size=8):
    resized = cv2.resize(image, (hash_size + 1, hash_size))
    diff = resized[:, 1:] > resized[:, :-1]
    return sum([2 ** i for (i, v) in enumerate(diff.flatten()) if v])

def remove_duplicates(data_dir):
    image_hashes = {}
    duplicates = []

    for category in os.listdir(data_dir):
        category_path = os.path.join(dest_dir, category)

        for img_name in os.listdir(category_path):
            img_path = os.path.join(category_path, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            img_hash = dhash(img)

            if img_hash in image_hashes:
                print(f"Duplicate found: {img_name} is a duplicate of {image_hashes[img_hash]}")
                duplicates.append(img_path)
            else:
                image_hashes[img_hash] = img_name

    for duplicate in duplicates:
        os.remove(duplicate)
        print(f"Deleted duplicate image: {duplicate}")

remove_duplicates(dest_dir)
# Out:
# Duplicate found: Tr-pi_0677.jpg is a duplicate of Tr-pi_0676.jpg
# Duplicate found: Tr-pi_0157.jpg is a duplicate of Tr-pi_0046.jpg
# Duplicate found: Tr-pi_0169.jpg is a duplicate of Tr-pi_0170.jpg
# Duplicate found: Tr-pi_0108.jpg is a duplicate of Tr-pi_0107.jpg
# Duplicate found: Tr-pi_0526.jpg is a duplicate of Tr-pi_0529.jpg
# Duplicate found: Tr-pi_0227.jpg is a duplicate of Tr-pi_0226.jpg
# Duplicate found: Tr-pi_0516.jpg is a duplicate of Tr-pi_0517.jpg
# Duplicate found: Tr-pi_0518.jpg is a duplicate of Tr-pi_0517.jpg
# Duplicate found: Tr-pi_0159.jpg is a duplicate of Tr-pi_0160.jpg
# Duplicate found: Tr-pi_0321.jpg is a duplicate of Tr-pi_0320.jpg
# Duplicate found: Tr-pi_0342.jpg is a duplicate of Tr-pi_0343.jpg
# Duplicate found: Tr-pi_0527.jpg is a duplicate of Tr-pi_0529.jpg
# Duplicate found: Tr-no_1513.jpg is a duplicate of Tr-no_0632.jpg
# Duplicate found: Tr-no_0270.jpg is a duplicate of Tr-no_0264.jpg
# Duplicate found: Tr-noTr_0003.jpg is a duplicate of Tr-no_0994.jpg
# Duplicate found: Tr-no_0384.jpg is a duplicate of Tr-no_0989.jpg
# Duplicate found: Tr-no_0336.jpg is a duplicate of Tr-no_1183.jpg
# Duplicate found: Tr-no_0119.jpg is a duplicate of Tr-no_0122.jpg
# Duplicate found: Tr-no_0152.jpg is a duplicate of Tr-no_1075.jpg
# Duplicate found: Tr-no_1544.jpg is a duplicate of Tr-no_0719.jpg
# Duplicate found: Tr-no_0960.jpg is a duplicate of Tr-no_0852.jpg
jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1046.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0766.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0898.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1479.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0352.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0244.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1026.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0977.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0213.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0452.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1069.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0282.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-noTr_0006.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1173.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0161.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0175.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1405.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1118.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1044.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1166.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0399.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0034.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1572.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1261.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0510.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0132.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0178.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1115.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0052.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0174.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1171.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0625.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1041.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1081.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0969.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0280.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0607.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0143.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1042.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0223.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1119.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0218.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1562.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1128.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0039.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0224.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1058.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0239.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0036.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1126.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1085.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0018.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0560.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0914.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0984.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1461.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0220.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1182.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1168.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_1049.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/notumor/Tr-no_0279.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0281.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0176.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0617.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0238.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0211.jpg
# Deleted duplicate image: /kaggle/working/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0249.jpg

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def load_and_preprocess_images(data_dir, target_size=(256, 256), categories=['notumor', 'glioma', 'meningioma', 'pituitary']):
    images = []
    labels = []
    valid_extensions = {'.png', '.jpg', '.jpeg', '.tif', '.tiff'}
    
    if not os.path.exists(data_dir):
        raise FileNotFoundError(f"The directory {data_dir} does not exist.")
    
    
    for idx, category in enumerate(categories):
        category_path = os.path.join(data_dir, category)
        if not os.path.exists(category_path):
            raise FileNotFoundError(f"The category directory {category_path} does not exist.")
        
        print(f"Processing category: {category}")
        for img_name in os.listdir(category_path):
            if any(img_name.lower().endswith(ext) for ext in valid_extensions):
                img_path = os.path.join(category_path, img_name)
                try:
                    img = load_img(img_path, color_mode='grayscale', target_size=target_size)
                    img_array = img_to_array(img)
                    images.append(img_array)
                    labels.append(idx)  # Label is the index of the category
                except Exception as e:
                    print(f"Error loading image {img_path}: {str(e)}")
    
    if not images:
        raise ValueError(f"No valid images found in the dataset.")
    
    print(f"Total images loaded: {len(images)}")
    
    
    images = np.array(images)
    labels = np.array(labels)
    
    return images, labels

def normalize_images(images):
    return (images / 127.5) - 1

def create_datasets(images, labels, batch_size=32, validation_split=0.2):
    if len(images) == 0 or len(labels) == 0:
        raise ValueError("The images or labels array is empty. Please check the data loading process.")
    
    
    labels = to_categorical(labels, num_classes=4)
    
    
    X_train, X_val, y_train, y_val = train_test_split(
        images, labels, test_size=validation_split, random_state=42, stratify=labels
    )
    
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(batch_size)
    val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size)
    
    print(f"Training set size: {len(X_train)}")
    print(f"Validation set size: {len(X_val)}")
    
    return train_dataset, val_dataset


data_dir = '/kaggle/working/brain-tumor-mri-dataset/Training'
categories = ['notumor', 'glioma', 'meningioma', 'pituitary']


if __name__ == "__main__":
    images, labels = load_and_preprocess_images(data_dir, categories=categories)
    normalized_images = normalize_images(images)
    
    
    train_dataset, val_dataset = create_datasets(normalized_images, labels)
    print("Datasets created successfully.")
# Out:
# Processing category: notumor
# Processing category: glioma
# Processing category: meningioma
# Processing category: pituitary
# Total images loaded: 5406
# Training set size: 4324
# Validation set size: 1082
# Datasets created successfully.

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


def create_resnet_model(input_shape=(256, 256, 1), num_classes=4):
    # Load the ResNet50 model, pre-trained on ImageNet and excluding the top layers
    base_model = ResNet50(weights=None, include_top=False, input_shape=input_shape)

    
    model = models.Sequential()
    model.add(base_model)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='softmax'))

    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model


input_shape = (256, 256, 1)
num_classes = 4
model = create_resnet_model(input_shape=input_shape, num_classes=num_classes)


early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-6)


history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=30,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729534987.264745      91 service.cc:145] XLA service 0x788e48004060 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729534987.264800      91 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729535014.696157      91 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_23', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1729535014.749542      91 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.4862 - loss: 1.6720
# I0000 00:00:1729535058.418870      92 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_23', 16 bytes spill stores, 16 bytes spill loads
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 111s 382ms/step - accuracy: 0.4869 - loss: 1.6686 - val_accuracy: 0.3863 - val_loss: 11.7321 - learning_rate: 0.0010
# Epoch 2/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 183ms/step - accuracy: 0.7185 - loss: 0.7512 - val_accuracy: 0.3161 - val_loss: 2.6409 - learning_rate: 0.0010
# Epoch 3/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 183ms/step - accuracy: 0.7509 - loss: 0.6732 - val_accuracy: 0.4048 - val_loss: 2.4493 - learning_rate: 0.0010
# Epoch 4/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 183ms/step - accuracy: 0.7900 - loss: 0.5687 - val_accuracy: 0.4621 - val_loss: 1.2788 - learning_rate: 0.0010
# Epoch 5/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 184ms/step - accuracy: 0.8178 - loss: 0.5295 - val_accuracy: 0.7384 - val_loss: 0.8433 - learning_rate: 0.0010
# Epoch 6/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 183ms/step - accuracy: 0.8470 - loss: 0.4404 - val_accuracy: 0.5619 - val_loss: 1.9063 - learning_rate: 0.0010
# Epoch 7/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.8605 - loss: 0.4092 - val_accuracy: 0.3854 - val_loss: 2.4561 - learning_rate: 0.0010
# Epoch 8/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.8671 - loss: 0.3747 - val_accuracy: 0.5351 - val_loss: 1.5169 - learning_rate: 0.0010
# Epoch 9/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 183ms/step - accuracy: 0.8903 - loss: 0.3197 - val_accuracy: 0.8965 - val_loss: 0.2836 - learning_rate: 1.0000e-04
# Epoch 10/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 183ms/step - accuracy: 0.9316 - loss: 0.1865 - val_accuracy: 0.9122 - val_loss: 0.2447 - learning_rate: 1.0000e-04
# Epoch 11/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.9401 - loss: 0.1845 - val_accuracy: 0.8780 - val_loss: 0.3554 - learning_rate: 1.0000e-04
# Epoch 12/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 181ms/step - accuracy: 0.9415 - loss: 0.1730 - val_accuracy: 0.8604 - val_loss: 0.4464 - learning_rate: 1.0000e-04
# Epoch 13/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.9480 - loss: 0.1650 - val_accuracy: 0.9187 - val_loss: 0.2275 - learning_rate: 1.0000e-04
# Epoch 14/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.9552 - loss: 0.1368 - val_accuracy: 0.9159 - val_loss: 0.2243 - learning_rate: 1.0000e-04
# Epoch 15/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 181ms/step - accuracy: 0.9614 - loss: 0.1164 - val_accuracy: 0.8133 - val_loss: 0.5306 - learning_rate: 1.0000e-04
# Epoch 16/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 181ms/step - accuracy: 0.9572 - loss: 0.1185 - val_accuracy: 0.9224 - val_loss: 0.2306 - learning_rate: 1.0000e-04
# Epoch 17/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 181ms/step - accuracy: 0.9700 - loss: 0.0959 - val_accuracy: 0.9094 - val_loss: 0.2813 - learning_rate: 1.0000e-04
# Epoch 18/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.9760 - loss: 0.0842 - val_accuracy: 0.9372 - val_loss: 0.2055 - learning_rate: 1.0000e-05
# Epoch 19/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.9789 - loss: 0.0647 - val_accuracy: 0.9473 - val_loss: 0.1836 - learning_rate: 1.0000e-05
# Epoch 20/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.9845 - loss: 0.0612 - val_accuracy: 0.9501 - val_loss: 0.1731 - learning_rate: 1.0000e-05
# Epoch 21/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 181ms/step - accuracy: 0.9879 - loss: 0.0450 - val_accuracy: 0.9529 - val_loss: 0.1777 - learning_rate: 1.0000e-05
# Epoch 22/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 180ms/step - accuracy: 0.9885 - loss: 0.0438 - val_accuracy: 0.9492 - val_loss: 0.1783 - learning_rate: 1.0000e-05
# Epoch 23/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 181ms/step - accuracy: 0.9886 - loss: 0.0428 - val_accuracy: 0.9492 - val_loss: 0.1845 - learning_rate: 1.0000e-05
# Epoch 24/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 24s 180ms/step - accuracy: 0.9843 - loss: 0.0493 - val_accuracy: 0.9529 - val_loss: 0.1767 - learning_rate: 1.0000e-06
# Epoch 25/30
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 180ms/step - accuracy: 0.9876 - loss: 0.0425 - val_accuracy: 0.9538 - val_loss: 0.1753 - learning_rate: 1.0000e-06

# %%
test_data_dir = '/kaggle/working/brain-tumor-mri-dataset/Testing'  # Change this to your actual test directory path

test_images, test_labels = load_and_preprocess_images(test_data_dir, categories=categories)
normalized_test_images = normalize_images(test_images)


test_labels_categorical = to_categorical(test_labels, num_classes=4)
test_dataset = tf.data.Dataset.from_tensor_slices((normalized_test_images, test_labels_categorical)).batch(32)

print(f"Test set size: {len(normalized_test_images)}")
# Out:
# Processing category: notumor
# Processing category: glioma
# Processing category: meningioma
# Processing category: pituitary
# Total images loaded: 1311
# Test set size: 1311

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9653 - loss: 0.1118
# Test Accuracy: 94.58%
# Test Loss: 0.1623

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns


test_predictions = model.predict(test_dataset)
test_pred_labels = np.argmax(test_predictions, axis=1)
true_test_labels = np.argmax(test_labels_categorical, axis=1)

print(classification_report(true_test_labels, test_pred_labels, target_names=categories))

cm = confusion_matrix(true_test_labels, test_pred_labels)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.title('Confusion Matrix on Test Data')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step
#               precision    recall  f1-score   support
#
#      notumor       0.94      0.99      0.96       405
#       glioma       0.97      0.94      0.95       300
#   meningioma       0.92      0.85      0.88       306
#    pituitary       0.96      0.99      0.98       300
#
#     accuracy                           0.95      1311
#    macro avg       0.95      0.94      0.94      1311
# weighted avg       0.95      0.95      0.95      1311

# %%
def visualize_predictions_on_test(model, test_dataset, num_images=5):
    test_images, test_labels = next(iter(test_dataset))
    predictions = model.predict(test_images)

    for i in range(num_images):
        plt.figure(figsize=(5, 5))
        plt.imshow(test_images[i].numpy().squeeze(), cmap='gray')
        pred_label = np.argmax(predictions[i])
        true_label = np.argmax(test_labels[i])
        plt.title(f'Pred: {categories[pred_label]}, True: {categories[true_label]}')
        plt.axis('off')
        plt.show()

visualize_predictions_on_test(model, test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 6))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()


plot_training_history(history)

# %%
model.save('/kaggle/working/resnet_brain_tumor_model.h5')
